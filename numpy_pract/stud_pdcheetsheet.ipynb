# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_csv('student.csv')

# %%
# new_std = df.to_csv('std1.csv')

# %%
df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob    NaN    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df.to_string()
# Out:
# '    id         name  class  mark  gender\n0    1     John Deo   Four    75  female\n1    2     Max Ruin  Three    85    male\n2    3       Arnold  Three    55    male\n3    4   Krish Star   Four    60  female\n4    5    John Mike   Four    60  female\n5    6    Alex John   Four    55    male\n6    7  My John Rob    NaN    78    male\n7    8       Asruid   Five    85    male\n8    9      Tes Qry    Six    78    male\n9   10     Big John   Four    55  female\n10  11       Ronald    Six    89  female\n11  12        Recky    Six    94  female\n12  13          Kty  Seven    88  female\n13  14         Bigy  Seven    88  female\n14  15     Tade Row   Four    88    male\n15  16        Gimmy   Four    88    male\n16  17        Tumyu    Six    54    male\n17  18        Honny   Five    75    male\n18  19        Tinny   Nine    18    male\n19  20       Jackly   Nine    65  female\n20  21   Babby John   Four    69  female\n21  22       Reggid  Seven    55  female\n22  23        Herod  Eight    7
# ...

# %%
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
df.shape
# Out:
# (35, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    35 non-null     object
#  2   class   33 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  34 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df['name'] = df['name'].astype('str')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    35 non-null     object
#  2   class   33 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  34 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.values
# Out:
# array([[1, 'John Deo', 'Four', 75, 'female'],
#        [2, 'Max Ruin', 'Three', 85, 'male'],
#        [3, 'Arnold', 'Three', 55, 'male'],
#        [4, 'Krish Star', 'Four', 60, 'female'],
#        [5, 'John Mike', 'Four', 60, 'female'],
#        [6, 'Alex John', 'Four', 55, 'male'],
#        [7, 'My John Rob', nan, 78, 'male'],
#        [8, 'Asruid', 'Five', 85, 'male'],
#        [9, 'Tes Qry', 'Six', 78, 'male'],
#        [10, 'Big John', 'Four', 55, 'female'],
#        [11, 'Ronald', 'Six', 89, 'female'],
#        [12, 'Recky', 'Six', 94, 'female'],
#        [13, 'Kty', 'Seven', 88, 'female'],
#        [14, 'Bigy', 'Seven', 88, 'female'],
#        [15, 'Tade Row', 'Four', 88, 'male'],
#        [16, 'Gimmy', 'Four', 88, 'male'],
#        [17, 'Tumyu', 'Six', 54, 'male'],
#        [18, 'Honny', 'Five', 75, 'male'],
#        [19, 'Tinny', 'Nine', 18, 'male'],
#        [20, 'Jackly', 'Nine', 65, 'female'],
#        [21, 'Babby John', 'Four', 69, 'female'],
# ...

# %%
df.sort_values('name', ascending = True)
# Out:
#     id         name  class  mark  gender
# 5    6    Alex John   Four    55    male
# 2    3       Arnold  Three    55    male
# 7    8       Asruid   Five    85    male
# 20  21   Babby John   Four    69  female
# 9   10     Big John   Four    55  female
# 26  27     Big Nose  Three    81  female
# 13  14         Bigy  Seven    88  female
# 31  32    Binn Rott  Seven    90  female
# 25  26       Crelea  Seven    79    male
# 33  34     Gain Toe    NaN    69    male
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 22  23        Herod  Eight    79    male
# 17  18        Honny   Five    75    male
# 19  20       Jackly   Nine    65  female
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 3    4   Krish Star   Four    60  female
# 12  13          Kty  Seven    88  female
# 30  31  Marry Toeey   Four    88     NaN
# 1    2     Max Ruin  Three    85    male
# ...

# %%
df.sort_index(ascending = False)
# Out:
#     id         name  class  mark  gender
# 34  35   Rows Noump    Six    88  female
# 33  34     Gain Toe    NaN    69    male
# 32  33    Kenn Rein    Six    96  female
# 31  32    Binn Rott  Seven    90  female
# 30  31  Marry Toeey   Four    88     NaN
# 29  30    Reppy Red    Six    79  female
# 28  29  Tess Played  Seven    55    male
# 27  28    Rojj Base  Seven    86  female
# 26  27     Big Nose  Three    81  female
# 25  26       Crelea  Seven    79    male
# 24  25     Giff Tow  Seven    88    male
# 23  24    Tiddy Now  Seven    78    male
# 22  23        Herod  Eight    79    male
# 21  22       Reggid  Seven    55  female
# 20  21   Babby John   Four    69  female
# 19  20       Jackly   Nine    65  female
# 18  19        Tinny   Nine    18    male
# 17  18        Honny   Five    75    male
# 16  17        Tumyu    Six    54    male
# 15  16        Gimmy   Four    88    male
# 14  15     Tade Row   Four    88    male
# 13  14         Bigy  Seven    88  female
# ...

# %%
df.rename(columns = {'name':'names', 'mark':'marks'})
# Out:
#     id        names  class  marks  gender
# 0    1     John Deo   Four     75  female
# 1    2     Max Ruin  Three     85    male
# 2    3       Arnold  Three     55    male
# 3    4   Krish Star   Four     60  female
# 4    5    John Mike   Four     60  female
# 5    6    Alex John   Four     55    male
# 6    7  My John Rob    NaN     78    male
# 7    8       Asruid   Five     85    male
# 8    9      Tes Qry    Six     78    male
# 9   10     Big John   Four     55  female
# 10  11       Ronald    Six     89  female
# 11  12        Recky    Six     94  female
# 12  13          Kty  Seven     88  female
# 13  14         Bigy  Seven     88  female
# 14  15     Tade Row   Four     88    male
# 15  16        Gimmy   Four     88    male
# 16  17        Tumyu    Six     54    male
# 17  18        Honny   Five     75    male
# 18  19        Tinny   Nine     18    male
# 19  20       Jackly   Nine     65  female
# 20  21   Babby John   Four     69  female
# ...

# %%
df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob    NaN    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df.rename(columns={'name':'names'},inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   names   35 non-null     object
#  2   class   33 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  34 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
pd.melt(df)
# Out:
#     variable   value
# 0         id       1
# 1         id       2
# 2         id       3
# 3         id       4
# 4         id       5
# ..       ...     ...
# 170   gender     NaN
# 171   gender  female
# 172   gender  female
# 173   gender    male
# 174   gender  female
#
# [175 rows x 2 columns]

# %%
df.drop(columns =['mark'] ,axis = 1)
# Out:
#     id        names  class  gender
# 0    1     John Deo   Four  female
# 1    2     Max Ruin  Three    male
# 2    3       Arnold  Three    male
# 3    4   Krish Star   Four  female
# 4    5    John Mike   Four  female
# 5    6    Alex John   Four    male
# 6    7  My John Rob    NaN    male
# 7    8       Asruid   Five    male
# 8    9      Tes Qry    Six    male
# 9   10     Big John   Four  female
# 10  11       Ronald    Six  female
# 11  12        Recky    Six  female
# 12  13          Kty  Seven  female
# 13  14         Bigy  Seven  female
# 14  15     Tade Row   Four    male
# 15  16        Gimmy   Four    male
# 16  17        Tumyu    Six    male
# 17  18        Honny   Five    male
# 18  19        Tinny   Nine    male
# 19  20       Jackly   Nine  female
# 20  21   Babby John   Four  female
# 21  22       Reggid  Seven  female
# 22  23        Herod  Eight    male
# 23  24    Tiddy Now  Seven    male
# 24  25     Giff Tow  Seven    male
# 25  26       Crelea  Seven    male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   names   35 non-null     object
#  2   class   33 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  34 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
drop_df = df.drop([2, 6], axis = 0)

# %%
df.head(5)
# Out:
#    id       names  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.tail(5)
# Out:
#     id        names  class  mark  gender
# 30  31  Marry Toeey   Four    88     NaN
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 33  34     Gain Toe    NaN    69    male
# 34  35   Rows Noump    Six    88  female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   names   35 non-null     object
#  2   class   33 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  34 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.sample(2)
# Out:
#     id        names  class  mark gender
# 28  29  Tess Played  Seven    55   male
# 6    7  My John Rob    NaN    78   male

# %%
df.nlargest(3,'mark')
# Out:
#     id      names  class  mark  gender
# 32  33  Kenn Rein    Six    96  female
# 11  12      Recky    Six    94  female
# 31  32  Binn Rott  Seven    90  female

# %%
df.nsmallest(3, 'mark')
# Out:
#     id   names  class  mark gender
# 18  19   Tinny   Nine    18   male
# 16  17   Tumyu    Six    54   male
# 2    3  Arnold  Three    55   male

# %%
df[df.mark < 19]
# Out:
#     id  names class  mark gender
# 18  19  Tinny  Nine    18   male

# %%
df[df.mark > 95]
# Out:
#     id      names class  mark  gender
# 32  33  Kenn Rein   Six    96  female

# %%
df['names']
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26       Big Nose
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: names, dtype: object

# %%
df[['names','mark']]
# Out:
#           names  mark
# 0      John Deo    75
# 1      Max Ruin    85
# 2        Arnold    55
# 3    Krish Star    60
# 4     John Mike    60
# 5     Alex John    55
# 6   My John Rob    78
# 7        Asruid    85
# 8       Tes Qry    78
# 9      Big John    55
# 10       Ronald    89
# 11        Recky    94
# 12          Kty    88
# 13         Bigy    88
# 14     Tade Row    88
# 15        Gimmy    88
# 16        Tumyu    54
# 17        Honny    75
# 18        Tinny    18
# 19       Jackly    65
# 20   Babby John    69
# 21       Reggid    55
# 22        Herod    79
# 23    Tiddy Now    78
# 24     Giff Tow    88
# 25       Crelea    79
# 26     Big Nose    81
# 27    Rojj Base    86
# 28  Tess Played    55
# 29    Reppy Red    79
# 30  Marry Toeey    88
# 31    Binn Rott    90
# 32    Kenn Rein    96
# 33     Gain Toe    69
# 34   Rows Noump    88

# %%
df.filter(regex = 'e|a')
# Out:
#           names  class  mark  gender
# 0      John Deo   Four    75  female
# 1      Max Ruin  Three    85    male
# 2        Arnold  Three    55    male
# 3    Krish Star   Four    60  female
# 4     John Mike   Four    60  female
# 5     Alex John   Four    55    male
# 6   My John Rob    NaN    78    male
# 7        Asruid   Five    85    male
# 8       Tes Qry    Six    78    male
# 9      Big John   Four    55  female
# 10       Ronald    Six    89  female
# 11        Recky    Six    94  female
# 12          Kty  Seven    88  female
# 13         Bigy  Seven    88  female
# 14     Tade Row   Four    88    male
# 15        Gimmy   Four    88    male
# 16        Tumyu    Six    54    male
# 17        Honny   Five    75    male
# 18        Tinny   Nine    18    male
# 19       Jackly   Nine    65  female
# 20   Babby John   Four    69  female
# 21       Reggid  Seven    55  female
# 22        Herod  Eight    79    male
# 23    Tiddy Now  Seven    78    male
# ...

# %%
df.loc[: , 'names':'mark']
# Out:
#           names  class  mark
# 0      John Deo   Four    75
# 1      Max Ruin  Three    85
# 2        Arnold  Three    55
# 3    Krish Star   Four    60
# 4     John Mike   Four    60
# 5     Alex John   Four    55
# 6   My John Rob    NaN    78
# 7        Asruid   Five    85
# 8       Tes Qry    Six    78
# 9      Big John   Four    55
# 10       Ronald    Six    89
# 11        Recky    Six    94
# 12          Kty  Seven    88
# 13         Bigy  Seven    88
# 14     Tade Row   Four    88
# 15        Gimmy   Four    88
# 16        Tumyu    Six    54
# 17        Honny   Five    75
# 18        Tinny   Nine    18
# 19       Jackly   Nine    65
# 20   Babby John   Four    69
# 21       Reggid  Seven    55
# 22        Herod  Eight    79
# 23    Tiddy Now  Seven    78
# 24     Giff Tow  Seven    88
# 25       Crelea  Seven    79
# 26     Big Nose  Three    81
# 27    Rojj Base  Seven    86
# 28  Tess Played  Seven    55
# 29    Reppy Red    Six    79
# 30  Marry Toeey   Four    88
# ...

# %%
df.loc[df['mark']> 95, ['names','mark']]
# Out:
#         names  mark
# 32  Kenn Rein    96

# %%
df.iloc[2:4]
# Out:
#    id       names  class  mark  gender
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female

# %%
df.iloc[: , [0 ,2]]
# Out:
#     id  class
# 0    1   Four
# 1    2  Three
# 2    3  Three
# 3    4   Four
# 4    5   Four
# 5    6   Four
# 6    7    NaN
# 7    8   Five
# 8    9    Six
# 9   10   Four
# 10  11    Six
# 11  12    Six
# 12  13  Seven
# 13  14  Seven
# 14  15   Four
# 15  16   Four
# 16  17    Six
# 17  18   Five
# 18  19   Nine
# 19  20   Nine
# 20  21   Four
# 21  22  Seven
# 22  23  Eight
# 23  24  Seven
# 24  25  Seven
# 25  26  Seven
# 26  27  Three
# 27  28  Seven
# 28  29  Seven
# 29  30    Six
# 30  31   Four
# 31  32  Seven
# 32  33    Six
# 33  34    NaN
# 34  35    Six

# %%
df.head(5)
# Out:
#    id       names  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.at[1,'mark']
# Out:
# np.int64(85)

# %%
df.iat[1, 2]
# Out:
# 'Three'

# %%
df.filter(items = ['names','class'])
# Out:
#           names  class
# 0      John Deo   Four
# 1      Max Ruin  Three
# 2        Arnold  Three
# 3    Krish Star   Four
# 4     John Mike   Four
# 5     Alex John   Four
# 6   My John Rob    NaN
# 7        Asruid   Five
# 8       Tes Qry    Six
# 9      Big John   Four
# 10       Ronald    Six
# 11        Recky    Six
# 12          Kty  Seven
# 13         Bigy  Seven
# 14     Tade Row   Four
# 15        Gimmy   Four
# 16        Tumyu    Six
# 17        Honny   Five
# 18        Tinny   Nine
# 19       Jackly   Nine
# 20   Babby John   Four
# 21       Reggid  Seven
# 22        Herod  Eight
# 23    Tiddy Now  Seven
# 24     Giff Tow  Seven
# 25       Crelea  Seven
# 26     Big Nose  Three
# 27    Rojj Base  Seven
# 28  Tess Played  Seven
# 29    Reppy Red    Six
# 30  Marry Toeey   Four
# 31    Binn Rott  Seven
# 32    Kenn Rein    Six
# 33     Gain Toe    NaN
# 34   Rows Noump    Six

# %%
df.filter(items = [34], axis = 0)
# Out:
#     id       names class  mark  gender
# 34  35  Rows Noump   Six    88  female

# %%
df['mark'].where(df['mark']>95)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32    96.0
# 33     NaN
# 34     NaN
# Name: mark, dtype: float64

# %%
df.query('mark > 95')
# Out:
#     id      names class  mark  gender
# 32  33  Kenn Rein   Six    96  female

# %%
df.query('mark < 95 and mark > 89 ')
# Out:
#     id      names  class  mark  gender
# 11  12      Recky    Six    94  female
# 31  32  Binn Rott  Seven    90  female

# %%
df.query("names.str.startswith('A')", )
# Out:
#    id      names  class  mark gender
# 2   3     Arnold  Three    55   male
# 5   6  Alex John   Four    55   male
# 7   8     Asruid   Five    85   male

# %%
df2 = pd.DataFrame({'names':["rahul","aniket"], 'class':["one","two"], "mark" : [20,30], 'gender':['male','female']})

# %%
df2
# Out:
#     names class  mark  gender
# 0   rahul   one    20    male
# 1  aniket   two    30  female

# %%
pd.merge(df, df2, how = 'left', on= "names")
# Out:
#     id        names class_x  mark_x gender_x class_y  mark_y gender_y
# 0    1     John Deo    Four      75   female     NaN     NaN      NaN
# 1    2     Max Ruin   Three      85     male     NaN     NaN      NaN
# 2    3       Arnold   Three      55     male     NaN     NaN      NaN
# 3    4   Krish Star    Four      60   female     NaN     NaN      NaN
# 4    5    John Mike    Four      60   female     NaN     NaN      NaN
# 5    6    Alex John    Four      55     male     NaN     NaN      NaN
# 6    7  My John Rob     NaN      78     male     NaN     NaN      NaN
# 7    8       Asruid    Five      85     male     NaN     NaN      NaN
# 8    9      Tes Qry     Six      78     male     NaN     NaN      NaN
# 9   10     Big John    Four      55   female     NaN     NaN      NaN
# 10  11       Ronald     Six      89   female     NaN     NaN      NaN
# 11  12        Recky     Six      94   female     NaN     NaN      NaN
# ...

# %%
df2 = pd.concat([df,df2],axis = 0, ignore_index=True)

# %%
df2
# Out:
#       id        names  class  mark  gender
# 0    1.0     John Deo   Four    75  female
# 1    2.0     Max Ruin  Three    85    male
# 2    3.0       Arnold  Three    55    male
# 3    4.0   Krish Star   Four    60  female
# 4    5.0    John Mike   Four    60  female
# 5    6.0    Alex John   Four    55    male
# 6    7.0  My John Rob    NaN    78    male
# 7    8.0       Asruid   Five    85    male
# 8    9.0      Tes Qry    Six    78    male
# 9   10.0     Big John   Four    55  female
# 10  11.0       Ronald    Six    89  female
# 11  12.0        Recky    Six    94  female
# 12  13.0          Kty  Seven    88  female
# 13  14.0         Bigy  Seven    88  female
# 14  15.0     Tade Row   Four    88    male
# 15  16.0        Gimmy   Four    88    male
# 16  17.0        Tumyu    Six    54    male
# 17  18.0        Honny   Five    75    male
# 18  19.0        Tinny   Nine    18    male
# 19  20.0       Jackly   Nine    65  female
# 20  21.0   Babby John   Four    69  female
# ...

# %%
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
df.names.unique()
# Out:
# array(['John Deo', 'Max Ruin', 'Arnold', 'Krish Star', 'John Mike',
#        'Alex John', 'My John Rob', 'Asruid', 'Tes Qry', 'Big John',
#        'Ronald', 'Recky', 'Kty', 'Bigy', 'Tade Row', 'Gimmy', 'Tumyu',
#        'Honny', 'Tinny', 'Jackly', 'Babby John', 'Reggid', 'Herod',
#        'Tiddy Now', 'Giff Tow', 'Crelea', 'Big Nose', 'Rojj Base',
#        'Tess Played', 'Reppy Red', 'Marry Toeey', 'Binn Rott',
#        'Kenn Rein', 'Gain Toe', 'Rows Noump'], dtype=object)

# %%
df.names.value_counts()
# Out:
# names
# John Deo       1
# Max Ruin       1
# Arnold         1
# Krish Star     1
# John Mike      1
# Alex John      1
# My John Rob    1
# Asruid         1
# Tes Qry        1
# Big John       1
# Ronald         1
# Recky          1
# Kty            1
# Bigy           1
# Tade Row       1
# Gimmy          1
# Tumyu          1
# Honny          1
# Tinny          1
# Jackly         1
# Babby John     1
# Reggid         1
# Herod          1
# Tiddy Now      1
# Giff Tow       1
# Crelea         1
# Big Nose       1
# Rojj Base      1
# Tess Played    1
# Reppy Red      1
# Marry Toeey    1
# Binn Rott      1
# Kenn Rein      1
# Gain Toe       1
# Rows Noump     1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   names   35 non-null     object
#  2   class   33 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  34 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df['mark'].sum()
# Out:
# np.int64(2613)

# %%
df['mark'].mean()
# Out:
# np.float64(74.65714285714286)

# %%
df['mark'].min()
# Out:
# np.int64(18)

# %%
df['mark'].max()
# Out:
# np.int64(96)

# %%
df['mark'].mean()
# Out:
# np.float64(74.65714285714286)

# %%
df['mark'].median()
# Out:
# np.float64(79.0)

# %%
df['mark'].var()
# Out:
# np.float64(268.99663865546216)

# %%
# apply custom function

# %%
df.isnull()
# Out:
#        id  names  class   mark  gender
# 0   False  False  False  False   False
# 1   False  False  False  False   False
# 2   False  False  False  False   False
# 3   False  False  False  False   False
# 4   False  False  False  False   False
# 5   False  False  False  False   False
# 6   False  False   True  False   False
# 7   False  False  False  False   False
# 8   False  False  False  False   False
# 9   False  False  False  False   False
# 10  False  False  False  False   False
# 11  False  False  False  False   False
# 12  False  False  False  False   False
# 13  False  False  False  False   False
# 14  False  False  False  False   False
# 15  False  False  False  False   False
# 16  False  False  False  False   False
# 17  False  False  False  False   False
# 18  False  False  False  False   False
# 19  False  False  False  False   False
# 20  False  False  False  False   False
# 21  False  False  False  False   False
# 22  False  False  False  False   False
# ...

# %%
def cutom_sum(col):
    if col.dtype != 'int64':
        return col.count()
    else:
        return col.sum()
df.apply(cutom_sum)
# Out:
# id         630
# names       35
# class       33
# mark      2613
# gender      34
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id        0
# names     0
# class     2
# mark      0
# gender    1
# dtype: int64

# %%
df['gender'] = df['gender'].dropna()

# %%
df
# Out:
#     id        names  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob    NaN    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df.dropna()
# Out:
#     id        names  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# 22  23        Herod  Eight    79    male
# ...

# %%
df.isnull().sum()
# Out:
# id        0
# names     0
# class     2
# mark      0
# gender    1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id        0
# names     0
# class     0
# mark      0
# gender    0
# dtype: int64

# %%
df.count()
# Out:
# id        32
# names     32
# class     32
# mark      32
# gender    32
# dtype: int64

# %%
Origin = pd.Series(data=['BH', 'J&K',
                         'BH', 'MP',
                         'WB', 'WB'])

# %%
df['Origin'] = Origin

# %%
df
# Out:
#     id        names  class  mark  gender Origin
# 0    1     John Deo   Four    75  female     BH
# 1    2     Max Ruin  Three    85    male    J&K
# 2    3       Arnold  Three    55    male     BH
# 3    4   Krish Star   Four    60  female     MP
# 4    5    John Mike   Four    60  female     WB
# 5    6    Alex John   Four    55    male     WB
# 7    8       Asruid   Five    85    male    NaN
# 8    9      Tes Qry    Six    78    male    NaN
# 9   10     Big John   Four    55  female    NaN
# 10  11       Ronald    Six    89  female    NaN
# 11  12        Recky    Six    94  female    NaN
# 12  13          Kty  Seven    88  female    NaN
# 13  14         Bigy  Seven    88  female    NaN
# 14  15     Tade Row   Four    88    male    NaN
# 15  16        Gimmy   Four    88    male    NaN
# 16  17        Tumyu    Six    54    male    NaN
# 17  18        Honny   Five    75    male    NaN
# 18  19        Tinny   Nine    18    male    NaN
# 19  20       Jackly   Nine    65  female    NaN
# ...

# %%
df.boxplot(column = 'mark', grid=False)
# Out:
# <Axes: >

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
